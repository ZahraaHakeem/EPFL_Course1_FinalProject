# %% [markdown]
# # A. An overview of the dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("p1_communes.csv")

# %%
print("It have " , df.shape[0] ," rows, and " , df.shape[1]," columns")
# Out:
# It have  2202  rows, and  17  columns

# %%
df.head(4)
# Out:
#   Canton             Commune Language  Residents  Population density per km²  \
# 0     ZH     Aeugst am Albis       de       1982                  250.568900
# 1     ZH  Affoltern am Albis       de      12229                 1154.768650
# 2     ZH          Bonstetten       de       5548                  746.702557
# 3     ZH     Hausen am Albis       de       3701                  272.132353
#
#    0-19 years  20-64 years  65 years or over  Private households  \
# 0   19.677094    62.764884         17.558022                 835
# 1   20.508627    61.329626         18.161747                5348
# 2   23.666186    60.310022         16.023792                2325
# 3   21.804918    60.686301         17.508781                1546
#
#    Surface area in km²  Settlement area  Agricultural area  Wooded area  \
# 0                 7.91        12.658228          51.139241    30.886076
# 1                10.59        30.674264          40.170940    28.205128
# 2                 7.43        15.456989          55.510753    28.629032
# 3                13.60        12.692590          55.906090    28.833456
#
#    Unproductive area  East coordinate  North coordinate  Elevation
# 0           5.316456          2679300           1235700        673
# 1           0.949668          2676800           1236800        502
# 2           0.403226          2677800           1241000        583
# 3           2.567865          2682900           1233100        653

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2202, step=1)

# %%
list(df.columns)
# Out:
# ['Canton',
#  'Commune',
#  'Language',
#  'Residents',
#  'Population density per km²',
#  '0-19 years',
#  '20-64 years',
#  '65 years or over',
#  'Private households',
#  'Surface area in km²',
#  'Settlement area',
#  'Agricultural area',
#  'Wooded area',
#  'Unproductive area',
#  'East coordinate',
#  'North coordinate',
#  'Elevation']

# %%
df.dtypes
# Out:
# Canton                         object
# Commune                        object
# Language                       object
# Residents                       int64
# Population density per km²    float64
# 0-19 years                    float64
# 20-64 years                   float64
# 65 years or over              float64
# Private households              int64
# Surface area in km²           float64
# Settlement area               float64
# Agricultural area             float64
# Wooded area                   float64
# Unproductive area             float64
# East coordinate                 int64
# North coordinate                int64
# Elevation                       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2202 entries, 0 to 2201
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Canton                      2199 non-null   object
#  1   Commune                     2202 non-null   object
#  2   Language                    2191 non-null   object
#  3   Residents                   2202 non-null   int64
#  4   Population density per km²  2202 non-null   float64
#  5   0-19 years                  2202 non-null   float64
#  6   20-64 years                 2202 non-null   float64
#  7   65 years or over            2202 non-null   float64
#  8   Private households          2202 non-null   int64
#  9   Surface area in km²         2202 non-null   float64
#  10  Settlement area             2202 non-null   float64
#  11  Agricultural area           2202 non-null   float64
#  12  Wooded area                 2202 non-null   float64
#  13  Unproductive area           2202 non-null   float64
#  14  East coordinate             2202 non-null   int64
#  15  North coordinate            2202 non-null   int64
#  16  Elevation                   2202 non-null   int64
# dtypes: float64(9), int64(5), object(3)
# memory usage: 292.6+ KB

# %% [markdown]
# **As you see above , Language and Canton have some missing values**

# %%
df.loc[df["Language"].isna(),:]
# Out:
#      Canton            Commune Language  Residents  \
# 155      ZH          Stammheim      NaN       2747
# 156      ZH          Wädenswil      NaN      24341
# 157      ZH               Elgg      NaN       4903
# 158      ZH             Horgen      NaN      22665
# 440     NaN            Thurnen      NaN       1922
# 704     NaN             Villaz      NaN       2287
# 757     NaN               Prez      NaN       2236
# 1133     GR     Bergün Filisur      NaN        905
# 1165     GR          Rheinwald      NaN        577
# 1626     TI            Riviera      NaN       4220
# 2079     NE  La Grande Béroche      NaN       8852
#
#       Population density per km²  0-19 years  20-64 years  65 years or over  \
# 155                   114.649416   21.405169    58.281762         20.313069
# 156                   682.968575   19.740356    59.944127         20.315517
# 157                   201.025010   20.762798    60.473180         18.764022
# 158                   735.160558   20.657401    60.480918         18.861681
# 440                   323.025210   20.759625    58.324662         20.915713
# 704                   148.217758   24.398776    61.346742         14.254482
# 757                   139.401496   25.000000    61.672630         13.327370
# 1133                    4.759651   16.574586    59.668508         23.756906
# 1165                    4.217220   16.984402    54.072790         28.942808
# 1626                   48.780488   20.071090    61.445498         18.483412
# 2079                  210.061699   21.159060    57.986896         20.854044
#
#       Private households  Surface area in km²  Settlement area  \
# 155                 1125                23.96         9.056761
# 156                10371                35.64        19.336706
# 157                 2121                24.39         9.545268
# 158                 9685                30.83        18.456049
# 440                  814                 5.95        13.949580
# 704                  897                15.44         8.808290
# 757                  839                16.04         6.924517
# 1133                 397               190.14         0.977815
# 1165                 266               136.82         1.124334
# 1626                1774                86.58         4.008317
# 2079                3918                42.13        11.591449
#
#       Agricultural area  Wooded area  Unproductive area  East coordinate  \
# 155           55.801336    34.557596           0.584307          2702400
# 156           63.265880    15.064643           2.332771          2693400
# 157           46.907005    43.138058           0.409668          2707700
# 158           38.858255    39.506974           3.178722          2687800
# 440           79.159664     6.050420           0.840336          2605300
# 704           70.336788    20.401554           0.453368          2563200
# 757           68.808484    23.268871           0.998129          2567700
# 1133          19.824414    27.541794          51.655977          2776700
# 1165          34.328685    14.448419          50.098562          2744500
# 1626           7.034770    65.553887          23.403026          2718700
# 2079          42.945368    44.608076           0.855107          2552500
#
#       North coordinate  Elevation
# 155            1276500        455
# 156            1231600        641
# 157            1260900        598
# 158            1234900        624
# 440            1184700        558
# 704            1174400        727
# 757            1181700        651
# 1133           1166700       2273
# 1165           1157500       2192
# 1626           1128900       1458
# 2079           1197900        686

# %%
df.loc[df["Canton"].isna(),:]
# Out:
#     Canton  Commune Language  Residents  Population density per km²  \
# 440    NaN  Thurnen      NaN       1922                  323.025210
# 704    NaN   Villaz      NaN       2287                  148.217758
# 757    NaN     Prez      NaN       2236                  139.401496
#
#      0-19 years  20-64 years  65 years or over  Private households  \
# 440   20.759625    58.324662         20.915713                 814
# 704   24.398776    61.346742         14.254482                 897
# 757   25.000000    61.672630         13.327370                 839
#
#      Surface area in km²  Settlement area  Agricultural area  Wooded area  \
# 440                 5.95        13.949580          79.159664     6.050420
# 704                15.44         8.808290          70.336788    20.401554
# 757                16.04         6.924517          68.808484    23.268871
#
#      Unproductive area  East coordinate  North coordinate  Elevation
# 440           0.840336          2605300           1184700        558
# 704           0.453368          2563200           1174400        727
# 757           0.998129          2567700           1181700        651

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (2191, 17)

# %% [markdown]
# # B. Exploration: numerical summaries, indexing and grouping

# %%
df.describe().T[["min","max","mean"]]
# Out:
#                                      min           max          mean
# Residents                   1.100000e+01  4.153670e+05  3.865300e+03
# Population density per km²  8.950366e-01  1.266905e+04  4.334240e+02
# 0-19 years                  0.000000e+00  3.777778e+01  2.058517e+01
# 20-64 years                 1.818182e+01  7.792208e+01  6.037118e+01
# 65 years or over            6.271186e+00  8.181818e+01  1.904365e+01
# Private households          1.000000e+01  2.012520e+05  1.702485e+03
# Surface area in km²         3.100000e-01  4.386300e+02  1.797283e+01
# Settlement area             1.388969e-01  9.726027e+01  1.488254e+01
# Agricultural area           0.000000e+00  9.150943e+01  4.592985e+01
# Wooded area                 0.000000e+00  8.823529e+01  3.257583e+01
# Unproductive area           0.000000e+00  9.502286e+01  6.611777e+00
# East coordinate             2.486700e+06  2.828800e+06  2.631543e+06
# North coordinate            1.077200e+06  1.294100e+06  1.202302e+06
# Elevation                   2.000000e+02  3.080000e+03  7.682095e+02

# %%
df = df.sort_values("Residents",ascending=False)
df.head(10)
# Out:
#      Canton      Commune Language  Residents  Population density per km²  \
# 154      ZH       Zürich       de     415367                 4723.837143
# 2124     GE       Genève       fr     201818                12669.052100
# 910      BS        Basel       de     172258                 7222.557652
# 1749     VD     Lausanne       fr     139111                 3361.793137
# 194      BE         Bern       de     133883                 2593.626501
# 141      ZH   Winterthur       de     111851                 1643.176142
# 535      LU       Luzern       de      81691                 2807.250859
# 1053     SG   St. Gallen       de      75833                 1925.672930
# 1582     TI       Lugano       it      63185                  832.915898
# 207      BE  Biel/Bienne       de      55159                 2603.067485
#
#       0-19 years  20-64 years  65 years or over  Private households  \
# 154    17.388719    67.684241         14.927040              201252
# 2124   17.946863    66.186366         15.866771               89672
# 910    16.834632    64.067852         19.097517               86350
# 1749   19.569984    65.735995         14.694021               68940
# 194    16.693680    66.047220         17.259099               63414
# 141    19.862138    63.889460         16.248402               50776
# 535    16.127848    64.419581         19.452571               41139
# 1053   18.076563    64.303140         17.620297               36992
# 1582   17.450344    60.397246         22.152410               30755
# 207    19.362207    62.337968         18.299824               26339
#
#       Surface area in km²  Settlement area  Agricultural area  Wooded area  \
# 154                 87.93        61.972472          10.101240    26.231373
# 2124                15.92        92.133417           1.510384     3.146633
# 910                 23.85        86.521557           3.850984     3.641691
# 1749                41.38        44.694223          16.050278    39.062122
# 194                 51.62        45.030033          18.988568    33.617516
# 141                 68.07        33.587786          24.823840    40.443335
# 535                 29.10        47.815617          27.863777    22.325421
# 1053                39.38        40.808543          28.960081    28.451564
# 1582                75.93        18.662806           9.607792    66.122664
# 207                 21.19        45.518868           7.877358    45.377358
#
#       Unproductive area  East coordinate  North coordinate  Elevation
# 154            1.694915          2683100           1247100        457
# 2124           3.209566          2500000           1117900        402
# 910            5.985768          2611300           1267600        266
# 1749           0.193377          2538200           1152400        667
# 194            2.363883          2600100           1199700        556
# 141            1.145038          2697200           1261700        481
# 535            1.995184          2666200           1211800        490
# 1053           1.779812          2746200           1254600        688
# 1582           5.606739          2717100           1095900        789
# 207            1.226415          2585500           1221200        478

# %%
df.tail(10)
# Out:
#                      index Canton Language  Residents  \
# Commune
# Bosco/Gurin           1627     TI       it         46
# Realp                  597     UR       de        153
# Fieschertal           1969     VS       de        318
# Avers                 1155     GR       de        168
# Bedretto              1533     TI       it        110
# Corippo               1546     TI       it         11
# Guttannen              408     BE       de        263
# Campo (Vallemaggia)   1628     TI       it         53
# Ferrera               1164     GR       de         75
# Zwischbergen          1953     VS       de         77
#
#                      Population density per km²  0-19 years  20-64 years  \
# Commune
# Bosco/Gurin                            2.089959    8.695652    60.869565
# Realp                                  1.965570    8.496732    56.862745
# Fieschertal                            1.840171   20.125786    61.320755
# Avers                                  1.804124   17.261905    55.357143
# Bedretto                               1.463155    6.363636    66.363636
# Corippo                                1.426719    0.000000    18.181818
# Guttannen                              1.309435   15.589354    50.950570
# Campo (Vallemaggia)                    1.223736    3.773585    60.377358
# Ferrera                                0.993904    8.000000    54.666667
# Zwischbergen                           0.895037    5.194805    77.922078
#
#                      65 years or over  Private households  \
# Commune
# Bosco/Gurin                 30.434783                  25
# Realp                       34.640523                  77
# Fieschertal                 18.553459                 133
# Avers                       27.380952                  75
# Bedretto                    27.272727                  58
# Corippo                     81.818182                  10
# Guttannen                   33.460076                 117
# Campo (Vallemaggia)         35.849057                  33
# Ferrera                     37.333333                  42
# Zwischbergen                16.883117                  43
#
#                      Surface area in km²  Settlement area  Agricultural area  \
# Commune
# Bosco/Gurin                        22.01         0.635786          24.386921
# Realp                              77.88         0.796813          38.748233
# Fieschertal                       172.86         0.138897           2.367035
# Avers                              93.12         0.472712          49.366137
# Bedretto                           75.19         0.996943          24.564668
# Corippo                             7.71         0.259740           3.506494
# Guttannen                         200.85         0.487951           3.813981
# Campo (Vallemaggia)                43.31         0.806266           8.500346
# Ferrera                            75.46         0.384411          24.774655
# Zwischbergen                       86.03         0.372353          11.252036
#
#                      Wooded area  Unproductive area  East coordinate  \
# Commune
# Bosco/Gurin            30.881017          44.096276          2681100
# Realp                   3.110140          57.344814          2681500
# Fieschertal             2.471208          95.022860          2654200
# Avers                   6.027073          44.134078          2759300
# Bedretto               15.047189          59.391200          2682300
# Corippo                64.935065          31.298701          2708100
# Guttannen               9.345748          86.352320          2665200
# Campo (Vallemaggia)    50.011518          40.681871          2681400
# Ferrera                17.948038          56.892895          2753800
# Zwischbergen           28.717710          59.657901          2654200
#
#                      North coordinate  Elevation
# Commune
# Bosco/Gurin                   1130000       2019
# Realp                         1161400       2413
# Fieschertal                   1141800       3080
# Avers                         1148900       2404
# Bedretto                      1151100       2244
# Corippo                       1121500       1134
# Guttannen                     1167600       2446
# Campo (Vallemaggia)           1126900       1805
# Ferrera                       1154100       2301
# Zwischbergen                  1116200       2129

# %% [markdown]
# **Grouping**

# %%
groups = df.groupby("Canton")
groups.get_group('ZH').to_csv('ZH.csv', encoding="utf-8")

# %%
df.groupby("Canton")["Population density per km²"].mean().sort_values(ascending=False)
# Out:
# Canton
# BS    3236.627458
# GE    1802.562712
# ZH     814.007380
# ZG     709.802261
# TI     644.134835
# BL     565.737021
# SG     535.510464
# AG     509.434515
# VD     435.300495
# SO     430.999314
# NE     424.794599
# TG     395.556296
# LU     386.478255
# SZ     384.974180
# NW     310.376483
# BE     292.678141
# FR     273.969971
# AR     267.894190
# SH     221.781214
# VS     144.689883
# AI     120.671860
# UR      95.559915
# GL      89.224440
# JU      87.176329
# OW      80.274054
# GR      62.352241
# Name: Population density per km², dtype: float64

# %%
groups.size().tail(5)
# Out:
# Canton
# UR     20
# VD    309
# VS    126
# ZG     11
# ZH    158
# dtype: int64

# %% [markdown]
# **We can notice the difference of Canton size in VS between previous and next code**

# %%
age_20_to_64 = df.loc[df["20-64 years"]>50 ,:]
age_20_to_64.groupby("Canton").size()
# Out:
# Canton
# AG    210
# AI      6
# AR     20
# BE    339
# BL     86
# BS      3
# FR    131
# GE     45
# GL      3
# GR    100
# JU     53
# LU     82
# NE     30
# NW     11
# OW      7
# SG     77
# SH     26
# SO    109
# SZ     29
# TG     80
# TI    113
# UR     20
# VD    309
# VS    124
# ZG     11
# ZH    158
# dtype: int64

# %%
elevationGroups= df.groupby("Canton")["Elevation"]
(elevationGroups.max() - elevationGroups.min()).sort_values(ascending=False).head(5)
df_Elev=pd.DataFrame([elevationGroups.max() ,  elevationGroups.min() ,elevationGroups.max() - elevationGroups.min()],index=["max","min","max-min"])
df_Elev.T
# Out:
#          max   min  max-min
# Canton
# AG       704   296      408
# AI      1280   848      432
# AR      1062   574      488
# BE      2446   421     2025
# BL       857   258      599
# BS       450   266      184
# FR      1420   432      988
# GE       482   366      116
# GL      1800  1213      587
# GR      2606   589     2017
# JU      1035   429      606
# LU      1364   420      944
# NE      1152   444      708
# NW      1512   502     1010
# OW      1745  1244      501
# SG      1829   400     1429
# SH       719   405      314
# SO      1022   347      675
# SZ      1684   413     1271
# TG       714   396      318
# TI      2244   200     2044
# UR      2413   542     1871
# VD      1666   374     1292
# VS      3080   470     2610
# ZG       958   398      560
# ZH       871   350      521

# %%
df_Elev.T.sort_values("max",ascending=False).head(5)
# Out:
#          max  min  max-min
# Canton
# VS      3080  470     2610
# GR      2606  589     2017
# BE      2446  421     2025
# UR      2413  542     1871
# TI      2244  200     2044

# %% [markdown]
# # C. Exploration: visualizations

# %% [markdown]
# ## 1

# %%
import matplotlib.pyplot as plt
df.reset_index().set_index("Commune")
df= df.sort_values("Residents",ascending=False)
values= df[:10]["Residents"]
colormap = plt.cm.tab10(range(0, len(values)))
plt.xlabel("Population density per km²")
plt.title("Top 10 populated communes in Switzerland")
values.plot.barh(color=colormap);

# %% [markdown]
# ## 2

# %%
values= df[:10][["Settlement area","Agricultural area","Wooded area","Unproductive area"]]
values.plot.barh(color=colormap,stacked=True);
plt.legend(bbox_to_anchor=(1.0, 1.0))
plt.title("top 10 populated communes by type of area")
plt.xlabel("area type in %");

# %% [markdown]
# ## 3

# %%
'''partsValues = []
partsNames = []
plt.figure(figsize=(5, 4));
for i in range(5,31,5):
    part = df.loc[(df["0-19 years"]>=i )& (df["0-19 years"]<i+5 ) ,:].shape[0]
    partsValues.append(part)
    partsNames.append( "{}%-{}%".format(i,i+5))
plt.bar(partsNames, partsValues, edgecolor="black")
plt.xticks(rotation='vertical')
plt.xlabel("Percentage")
plt.ylabel("Communes")
plt.title("Percentage of the age of 0-19 years in the communes");
print(partsValues)'''

# %%
plt.figure(figsize=(5,4));
binsHis= range(5,36,5)
binsHisNames = [str(x)+'%' for x in binsHis]
y, x, _ = plt.hist(df["0-19 years"],bins=binsHis)
#plt.xticks(rotation='vertical')
plt.xticks(
    binsHis,  # list of list of xtick locations
    binsHisNames,  # list of labels
)
plt.xlabel("Percentage")
plt.ylabel("Communes")
plt.title("Percentage of the age of 0-19 years in the communes")
plt.ylim(0,y.max()+50);
#plt.locator_params(axis='y', nbins=100);

# %% [markdown]
# ## 4

# %%
sns.violinplot(x="Language", y="0-19 years", data=df, hue="Language")
plt.title("Distribution of age group 0-19 years by language")
plt.xlabel("Language")
plt.ylabel("Percentage of 0-19 years residents")
plt.legend(bbox_to_anchor=(1.0, 1.0))

# %% [markdown]
# ## 5

# %%
fig, axi = plt.subplots(nrows = 1,  # sets the number of rows in the subplot grid
                         ncols = 3,  # sets the number of columns in the subplot grid
                         figsize = (12, 3.5) , # sets the width and height of the figure (in inches)
                         sharey=True , # make all subplots share the same y-axix
                         gridspec_kw = {"wspace": 0.2  # Sets the width of padding between subplots (is a fraction of the Axes width)
                                         # Sets relative width ratios between subplots 
                                       }
                        )
sns.set()
ages = ['0-19 years','20-64 years','65 years or over']
for i, ax in zip(range(0, 3), axi.flatten()):    
    sns.violinplot(data=df, x="Language", y=ages[i], ax=axi[i],hue="Language")
    plt.
   
    
plt.show()
